# %%
import torch
import cv2
import numpy as np
from ultralytics import YOLO

device = "cuda" if torch.cuda.is_available() else "cpu"

# 모델 로드
model = YOLO('yolo11n.pt').to(device)  # 학습된 가중치 경로

# 이미지 불러오기
image_path = "data/bart_simpson/pic_0000.jpg"
img = cv2.imread(image_path)

# 이미지 전처리
img0 = img.copy()
img = letterbox(img, 640, stride=32)[0]  # YOLO 모델 입력 크기로 맞춤
img = img.transpose(2, 0, 1)[::-1]  # BGR to RGB, to 3x640x640
img = np.ascontiguousarray(img)

# 이미지 텐서로 변환
img = torch.from_numpy(img).to('cuda').float()
img /= 255.0  # 0 - 1 범위로 정규화
if len(img.shape) == 3:
    img = img.unsqueeze(0)  # 배치 크기 추가

# 추론 수행
with torch.no_grad():
    pred = model(img)
    pred = non_max_suppression(pred, 0.25, 0.45, classes=None, agnostic=False)

# 탐지된 결과 확인 및 라벨 추출
for i, det in enumerate(pred):  # 탐지 결과마다 반복
    if len(det):
        # 이미지 크기 조정
        det[:, :4] = scale_coords(img.shape[2:], det[:, :4], img0.shape).round()
        
        # 탐지된 얼굴에 대한 라벨 출력
        for *xyxy, conf, cls in reversed(det):
            label = f'{cls} {conf:.2f}'  # 클래스와 신뢰도
            print(f"좌표: {xyxy}, 라벨: {label}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      15 # 이미지 전처리
#      16 img0 = img.copy()
# ---> 17 img = letterbox(img, 640, stride=32)[0]  # YOLO 모델 입력 크기로 맞춤
#      18 img = img.transpose(2, 0, 1)[::-1]  # BGR to RGB, to 3x640x640
#      19 img = np.ascontiguousarray(img)
#
# NameError: name 'letterbox' is not defined

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from PIL import Image  # Import the Image class from Pillow library

# 모델 로드
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

# 이미지 전처리
transform = transforms.Compose([
    transforms.ToTensor()
])

# 이미지 읽고 추론
img = Image.open('data/bart_simpson/pic_0000.jpg')
img_tensor = transform(img)
img_tensor = img_tensor.unsqueeze(0)

with torch.no_grad():
    outputs = model([img_tensor])

# 결과 출력
for box in outputs[0]['boxes']:
    print(box) # 각 박스의 좌표 출력
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 21
#      18 img_tensor = img_tensor.unsqueeze(0)
#      20 with torch.no_grad():
# ---> 21     outputs = model([img_tensor])
#      23 # 결과 출력
#      24 for box in outputs[0]['boxes']:
#
# File C:\Users\sba\miniconda3\envs\album\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File C:\Users\sba\miniconda3\envs\album\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
# ...

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from PIL import Image  # Import Image class from Pillow
from ultralytics import YOLO

device = "cuda" if torch.cuda.is_available() else "cpu"

# 모델 로드
model = YOLO('yolo11n.pt').to(device)  # 학습된 가중치 경로

# # Load the model with updated weights argument
# model = torchvision.models.detection.fasterrcnn_resnet50_fpn(
#     weights=torchvision.models.detection.FasterRCNN_ResNet50_FPN_Weights.DEFAULT
# )
# model.eval()  # Set the model to evaluation mode

# Preprocess the image
transform = transforms.Compose([
    transforms.ToTensor()
])

# Read the image and convert to a tensor
img_path = 'data/bart_simpson/pic_0000.jpg'  # Replace with your image path
try:
    img = Image.open(img_path)
except FileNotFoundError:
    print(f"Error: Image file '{img_path}' not found.")
    exit()

img_tensor = transform(img)
img_tensor = img_tensor.unsqueeze(0)  # Add a batch dimension

# Perform inference (replace with actual YOLOv11 code once implemented)
with torch.no_grad():
    outputs = model([img_tensor])

# Process the inference results (replace with YOLOv11-specific logic)
for box in outputs[0]['boxes']:
    print(box)  # Example: print bounding box coordinates
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 36
#      34 # Perform inference (replace with actual YOLOv11 code once implemented)
#      35 with torch.no_grad():
# ---> 36     outputs = model([img_tensor])
#      38 # Process the inference results (replace with YOLOv11-specific logic)
#      39 for box in outputs[0]['boxes']:
#
# File C:\Users\sba\miniconda3\envs\album\lib\site-packages\ultralytics\engine\model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     147 def __call__(
#     148     self,
#     149     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     150     stream: bool = False,
#     151     **kwargs,
#     152 ) -> list:
#     153     """
#     154     Alias for the predict method, enabling the model instance to be callable for predictions.
#     155
#    (...)
# ...

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
from ultralytics import YOLO
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"

# 모델 로드
model = YOLO('yolo11n.pt').to(device)  # 학습된 가중치 경로

# Preprocess the image
transform = transforms.Compose([
    transforms.Resize((416, 416)),  # Adjust size as needed
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Adjust normalization values if necessary
])

# Load the image using Matplotlib
image = plt.imread('data/bart_simpson/pic_0000.jpg')

# Convert the image to a NumPy array
img_np = np.array(image)

# # # Preprocess the image
# # img_tensor = transform(img).unsqueeze(0)

# # Preprocess the image (assuming ultralytics handles normalization)
# img = model(img)  # Let ultralytics handle preprocessing

# # Perform inference
with torch.no_grad():
    detections = model(img_tensor)

# Process detections (replace with your specific logic)
# img_np = img.numpy().transpose(1, 2, 0)  # Convert to numpy array and transpose
img_np = img_np * 255  # Convert from [0, 1] to [0, 255]
for detection in detections:
    # Extract bounding box, class, and confidence
    x, y, w, h, confidence, class_id = detection

    # Calculate bounding box coordinates
    x_center, y_center = x * img.shape[1], y * img.shape[2]
    width, height = w * img.shape[1], h * img.shape[2]
    x1, y1 = int(x_center - width / 2), int(y_center - height / 2)
    x2, y2 = int(x_center + width / 2), int(y_center + height / 2)

    # Draw bounding box and label
    cv2.rectangle(img_np, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img_np, f"{class_names[class_id]} ({confidence:.2f})", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

# Display the image
cv2.imshow('Detections', img_np)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 40
#      37 img_np = img_np * 255  # Convert from [0, 1] to [0, 255]
#      38 for detection in detections:
#      39     # Extract bounding box, class, and confidence
# ---> 40     x, y, w, h, confidence, class_id = detection
#      42     # Calculate bounding box coordinates
#      43     x_center, y_center = x * img.shape[1], y * img.shape[2]
#
# ValueError: not enough values to unpack (expected 6, got 0)
